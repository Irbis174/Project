# %%
import xml.etree.ElementTree as ET
from os import listdir
import os
from os.path import isfile, join
import pandas as pd

# %%
fn = 'data/train/Accident'

# %%
p = [fn + '/' + f for f in listdir(fn) if isfile(join(fn, f)) and f[-1] == 'l']

# %%
p = sorted(p, key=lambda x: int(''.join(filter(str.isdigit, x))))

# %%
p
# Out:
# ['data/train/Accident/test (1).xml',
#  'data/train/Accident/test (2).xml',
#  'data/train/Accident/test (3).xml',
#  'data/train/Accident/test (4).xml',
#  'data/train/Accident/test (5).xml',
#  'data/train/Accident/test (6).xml',
#  'data/train/Accident/test (7).xml',
#  'data/train/Accident/test (8).xml',
#  'data/train/Accident/test (9).xml',
#  'data/train/Accident/test (10).xml',
#  'data/train/Accident/test (11).xml',
#  'data/train/Accident/test (12).xml',
#  'data/train/Accident/test (13).xml',
#  'data/train/Accident/test (14).xml',
#  'data/train/Accident/test (15).xml',
#  'data/train/Accident/test (16).xml',
#  'data/train/Accident/test (17).xml',
#  'data/train/Accident/test (18).xml',
#  'data/train/Accident/test (19).xml',
#  'data/train/Accident/test (20).xml',
#  'data/train/Accident/test (21).xml',
#  'data/train/Accident/test (22).xml',
#  'data/train/Accident/test (23).xml',
#  'data/train/Accident/test (24).xml',
#  'data/train/Accident/test (25).xml',
#  'data/train/Accident/test (26).xml',
#  'data/train/Accident/test (27).xml',
#  'data/train/Accident/test (28).xml',
#  'data/train/Accident/test (29).xml',
#  'data/train/Accident/test (30).xml',
#  'data/train/Accident/test (31).xml',
#  'data/train/Accident/test (32).xml',
#  'data/train/Accident/test (33).xml',
#  'data/train/Accident/test (34).xml',
#  'data/train/Accident/test (35).xml',
#  'data/train/Accident/test (36).xml',
#  'data/train/Accident/test (37).xml',
#  'data/train/Accident/test (38).xml',
#  'data/train/Accident/test (39).xml',
#  'data/train/Accident/test (40).xml',
#  'data/train/Accident/test (41).xml',
#  'data/train/Accident/test (42).xml',
#  'data/train/Accident/test (43).xml',
#  'data/train/Accident/test (44).xml',
#  'data/train/Accident/test (45).xml',
#  'data/train/Accident/test (46).xml',
#  'data/train/Accident/test (47).xml',
#  'data/train/Accident/test (48).xml',
#  'data/train/Accident/test (49).xml',
#  'data/train/Accident/test (50).xml',
#  'data/train/Accident/test (51).xml',
#  'data/train/Accident/test (52).xml',
#  'data/train/Accident/test (53).xml',
#  'data/train/Accident/test (54).xml',
#  'data/train/Accident/test (55).xml',
#  'data/train/Accident/test (56).xml',
#  'data/train/Accident/test (57).xml',
#  'data/train/Accident/test (58).xml',
#  'data/train/Accident/test (59).xml',
#  'data/train/Accident/test (60).xml',
#  'data/train/Accident/test (61).xml',
#  'data/train/Accident/test (62).xml',
#  'data/train/Accident/test (63).xml',
#  'data/train/Accident/test (64).xml',
#  'data/train/Accident/test (65).xml',
#  'data/train/Accident/test (66).xml',
#  'data/train/Accident/test (67).xml',
#  'data/train/Accident/test (68).xml',
#  'data/train/Accident/test (69).xml',
#  'data/train/Accident/test (70).xml',
#  'data/train/Accident/test (71).xml',
#  'data/train/Accident/test (72).xml',
#  'data/train/Accident/test (73).xml',
#  'data/train/Accident/test (74).xml',
#  'data/train/Accident/test (75).xml',
#  'data/train/Accident/test (76).xml',
#  'data/train/Accident/test (77).xml',
#  'data/train/Accident/test (78).xml',
#  'data/train/Accident/test (79).xml',
#  'data/train/Accident/test (80).xml',
#  'data/train/Accident/test (81).xml',
#  'data/train/Accident/test (82).xml',
#  'data/train/Accident/test (83).xml',
#  'data/train/Accident/test (84).xml',
#  'data/train/Accident/test (85).xml',
#  'data/train/Accident/test (86).xml',
#  'data/train/Accident/test (87).xml',
#  'data/train/Accident/test (88).xml',
#  'data/train/Accident/test (89).xml',
#  'data/train/Accident/test (90).xml',
#  'data/train/Accident/test (91).xml',
#  'data/train/Accident/test (92).xml',
#  'data/train/Accident/test (93).xml',
#  'data/train/Accident/test (94).xml',
#  'data/train/Accident/test (95).xml',
#  'data/train/Accident/test (96).xml',
#  'data/train/Accident/test (97).xml',
#  'data/train/Accident/test (98).xml',
#  'data/train/Accident/test (99).xml',
#  'data/train/Accident/test (100).xml',
#  'data/train/Accident/test (101).xml',
#  'data/train/Accident/test (102).xml',
#  'data/train/Accident/test (103).xml',
#  'data/train/Accident/test (104).xml',
#  'data/train/Accident/test (105).xml',
#  'data/train/Accident/test (106).xml',
#  'data/train/Accident/test (107).xml',
#  'data/train/Accident/test (108).xml',
#  'data/train/Accident/test (109).xml',
#  'data/train/Accident/test (110).xml',
#  'data/train/Accident/test (111).xml',
#  'data/train/Accident/test (112).xml',
#  'data/train/Accident/test (113).xml',
#  'data/train/Accident/test (114).xml',
#  'data/train/Accident/test (115).xml',
#  'data/train/Accident/test (116).xml',
#  'data/train/Accident/test (117).xml',
#  'data/train/Accident/test (118).xml',
#  'data/train/Accident/test (119).xml',
#  'data/train/Accident/test (120).xml',
#  'data/train/Accident/test (121).xml',
#  'data/train/Accident/test (122).xml',
#  'data/train/Accident/test (123).xml',
#  'data/train/Accident/test (124).xml',
#  'data/train/Accident/test (125).xml',
#  'data/train/Accident/test (126).xml',
#  'data/train/Accident/test (127).xml',
#  'data/train/Accident/test (128).xml',
#  'data/train/Accident/test (129).xml',
#  'data/train/Accident/test (130).xml',
#  'data/train/Accident/test (131).xml',
#  'data/train/Accident/test (132).xml',
#  'data/train/Accident/test (133).xml',
#  'data/train/Accident/test (134).xml',
#  'data/train/Accident/test (135).xml',
#  'data/train/Accident/test (136).xml',
#  'data/train/Accident/test (137).xml',
#  'data/train/Accident/test (138).xml',
#  'data/train/Accident/test (139).xml',
#  'data/train/Accident/test (140).xml',
#  'data/train/Accident/test (141).xml',
#  'data/train/Accident/test (142).xml',
#  'data/train/Accident/test (143).xml',
#  'data/train/Accident/test (144).xml',
#  'data/train/Accident/test (145).xml',
#  'data/train/Accident/test (146).xml',
#  'data/train/Accident/test (147).xml',
#  'data/train/Accident/test (148).xml',
#  'data/train/Accident/test (149).xml',
#  'data/train/Accident/test (150).xml',
#  'data/train/Accident/test (151).xml',
#  'data/train/Accident/test (152).xml',
#  'data/train/Accident/test (153).xml',
#  'data/train/Accident/test (154).xml',
#  'data/train/Accident/test (155).xml',
#  'data/train/Accident/test (156).xml',
#  'data/train/Accident/test (157).xml',
#  'data/train/Accident/test (158).xml',
#  'data/train/Accident/test (159).xml',
#  'data/train/Accident/test (160).xml',
#  'data/train/Accident/test (161).xml',
#  'data/train/Accident/test (162).xml',
#  'data/train/Accident/test (163).xml',
#  'data/train/Accident/test (164).xml',
#  'data/train/Accident/test (165).xml',
#  'data/train/Accident/test (166).xml',
#  'data/train/Accident/test (167).xml',
#  'data/train/Accident/test (168).xml',
#  'data/train/Accident/test (169).xml',
#  'data/train/Accident/test (170).xml',
#  'data/train/Accident/test (171).xml',
#  'data/train/Accident/test (172).xml',
#  'data/train/Accident/test (173).xml',
#  'data/train/Accident/test (174).xml',
#  'data/train/Accident/test (175).xml',
#  'data/train/Accident/test (176).xml',
#  'data/train/Accident/test (177).xml',
#  'data/train/Accident/test (178).xml',
#  'data/train/Accident/test (179).xml',
#  'data/train/Accident/test (180).xml',
#  'data/train/Accident/test (181).xml',
#  'data/train/Accident/test (182).xml',
#  'data/train/Accident/test (183).xml',
#  'data/train/Accident/test (184).xml',
#  'data/train/Accident/test (185).xml',
#  'data/train/Accident/test (186).xml',
#  'data/train/Accident/test (187).xml',
#  'data/train/Accident/test (188).xml',
#  'data/train/Accident/test (189).xml',
#  'data/train/Accident/test (190).xml',
#  'data/train/Accident/test (191).xml',
#  'data/train/Accident/test (192).xml',
#  'data/train/Accident/test (193).xml',
#  'data/train/Accident/test (194).xml',
#  'data/train/Accident/test (195).xml',
#  'data/train/Accident/test (196).xml',
#  'data/train/Accident/test (197).xml',
#  'data/train/Accident/test (198).xml',
#  'data/train/Accident/test (199).xml',
#  'data/train/Accident/test (200).xml',
#  'data/train/Accident/test (201).xml',
#  'data/train/Accident/test (202).xml',
#  'data/train/Accident/test (203).xml',
#  'data/train/Accident/test (204).xml',
#  'data/train/Accident/test (205).xml',
#  'data/train/Accident/test (206).xml',
#  'data/train/Accident/test (207).xml',
#  'data/train/Accident/test (208).xml',
#  'data/train/Accident/test (209).xml',
#  'data/train/Accident/test (210).xml',
#  'data/train/Accident/test (211).xml',
#  'data/train/Accident/test (212).xml',
#  'data/train/Accident/test (213).xml',
#  'data/train/Accident/test (214).xml',
#  'data/train/Accident/test (215).xml',
#  'data/train/Accident/test (216).xml',
#  'data/train/Accident/test (217).xml',
#  'data/train/Accident/test (218).xml',
#  'data/train/Accident/test (219).xml',
#  'data/train/Accident/test (220).xml',
#  'data/train/Accident/test (221).xml',
#  'data/train/Accident/test (222).xml',
#  'data/train/Accident/test (223).xml',
#  'data/train/Accident/test (224).xml',
#  'data/train/Accident/test (225).xml',
#  'data/train/Accident/test (226).xml',
#  'data/train/Accident/test (227).xml',
#  'data/train/Accident/test (228).xml',
#  'data/train/Accident/test (229).xml',
#  'data/train/Accident/test (230).xml',
#  'data/train/Accident/test (231).xml']

# %%
def data(p,filename, accidents,width,height,xmin,ymin,xmax,ymax):
    for xml in p:
        tree = ET.parse(xml) #адрес файла
        root=tree.getroot()   #парсим
        num_objects = len(root)-6
        cords = []
        w = int(root[4][0].text) #ширина x
        h = int(root[4][1].text) #высота y
        #print(xml)
        filename.append(xml.replace('.xml','.jpg').replace('data/train/Accident/',''))
        width.append(w)
        height.append(h)
        xmin.append(root[6][4][0].text)
        ymin.append(root[6][4][1].text)
        xmax.append(root[6][4][2].text)
        ymax.append(root[6][4][3].text)
        accidents.append('accidents')
    return filename,accidents,width,height,xmin,ymin,xmax,ymax

# %%
filename = []
accidents = []
width = []
height = []
xmin = []
ymin = []
xmax = []
ymax = []
filename, accidents, width, height, xmin, ymin, xmax, ymax = data(p,filename, accidents,width,height,xmin,ymin,xmax,ymax)#,accidents,width,height)#,xmin,ymin,xmax,ymax)

# %%
df_acc = pd.DataFrame({'filename' :filename,'width': width, 'height': height, 'class': accidents,'xmin':xmin, 'ymin': ymin, 'xmax':xmax,'ymax': ymax})

# %%
df_acc
# Out:
#            filename  width  height      class xmin ymin  xmax ymax
# 0      test (1).jpg   1280     720  accidents  188  100   579  237
# 1      test (2).jpg   1280     720  accidents  197  106   615  249
# 2      test (3).jpg   1280     720  accidents  188  119   644  286
# 3      test (4).jpg   1280     720  accidents  354  204   575  281
# 4      test (5).jpg   1280     720  accidents  330  208   552  281
# ..              ...    ...     ...        ...  ...  ...   ...  ...
# 226  test (227).jpg   1280     720  accidents  524  190  1140  720
# 227  test (228).jpg   1280     720  accidents  522  194  1136  720
# 228  test (229).jpg   1280     720  accidents  520  194  1138  720
# 229  test (230).jpg   1280     720  accidents  522  196  1137  720
# 230  test (231).jpg   1280     720  accidents  525  190  1139  720
#
# [231 rows x 8 columns]

# %%
df_acc = df_acc.to_csv('data/train/Accident/accidents.csv', encoding='utf-8')
