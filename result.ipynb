# %%
import PIL.Image
import numpy as np
from keras.models import load_model
import tensorflow as tf
import cv2 
import matplotlib.pyplot as plt

# %%
#Загрузка моделей
model_car = load_model('Модели\\cars_best.h5')
model_acc = load_model('Модели\\class.h5')
model_loc = load_model('Модели\\loc.h5')
global model_loc
global model_acc
global model_car

# %%
#Подготовка изображения 
def _preprocessing_image(image, model):
    image = PIL.Image.open(image)
    image = image.resize((208, 208))
    arr = np.array(image)
    arr = arr.reshape(1, 208, 208, 3)
    predictions = model.predict(arr)

    return arr, predictions,image

# %%
def predict(name):
    # функция приводит данные в надлежащий вид
    x_car,y_car,img = _preprocessing_image(name, model_car)
    x_acc,y_acc,img = _preprocessing_image(name, model_acc)
    # предсказания модели
    if (100 - round((y_car[0][0]) * 100) > 30) and (y_acc[0][0]*100>=25): return (1,'Обнаружена авария',img)
    elif (100 - round((y_car[0][0]) * 100) < 30): return (2,'Ничего не обнаружено',img)
    elif (100 - round((y_car[0][0]) * 100) > 30) and not(y_acc[0][0]*100>=25): return (0,'Обнаружена машина',img)

# %%
def predict_bounding_box(image):
    img_class, dtype, img = predict(image)
    images, prediction, img = _preprocessing_image(image, model_loc)
    images = np.array(images)
    prediction = np.array(prediction)
    if img_class == 0: 
        print(dtype)
        bounding_box(images,prediction,(0,255,0),text = 'Car')
    elif img_class == 1:
        print(dtype)
        bounding_box(images,prediction,(0,0,255),text = 'Accidents')
    elif img_class == 2:
        print(dtype)
        bounding_box(images,dtype = False)

# %%
def bounding_box(images, prediction = None,frame = None,text = None,dtype = None):
    #Для машины или аварии
    if dtype is None:
        for i, pred in enumerate(images):
            x, y, w, h = prediction[i]
            b,g,r=cv2.split(pred)
            pred=cv2.merge((r,g,b)) 
            cv2.rectangle(pred, (int(x), int(y)), (int(w), int(h)), frame, 1) #Отрисовка рамки
            cv2.putText(pred,text,(int(x), int(y-2)),cv2.FONT_HERSHEY_DUPLEX,0.3,frame,1,100) #Отрисовка текста
            plt.figure(figsize=(5,5))
            plt.imshow(pred[:,:,::-1])
    else:
        #Для других объектов
        for i, pred in enumerate(images):
            b,g,r=cv2.split(pred)
            pred=cv2.merge((r,g,b))
            plt.figure(figsize=(5,5))
            plt.imshow(pred[:,:,::-1])

# %%
#Ничего
predict_bounding_box('C:\\Users\\Matvey\\Downloads\\проверка\\iStock-494239087-thumb.jpg')
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020DDB5760D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020DE25AC3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Ничего не обнаружено

# %%
#Машина
predict_bounding_box('C:\\Users\\Matvey\\Downloads\\проверка\\18015-MC20BluInfinito-scaled-e1666008987698.jpg')
# Out:
# Обнаружена машина

# %%
#Авария
predict_bounding_box('C:\\Users\\Matvey\\Downloads\\проверка\\Без названия11.jpg')
# Out:
# Обнаружена авария
